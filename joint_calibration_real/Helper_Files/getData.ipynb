# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../Data/OPTSTK_RELIANCE_CE_01-Jan-2025_TO_08-Jan-2025.csv')
data.columns = data.columns.str.strip()
data.tail()
# Out:
#        Symbol         Date       Expiry Option type  Strike Price   Open  \
# 619  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1200.0  58.00
# 620  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1020.0      -
# 621  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1040.0      -
# 622  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1210.0  55.10
# 623  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1220.0  46.10
#
#       High    Low   Close    LTP Settle Price No. of contracts  \
# 619  63.75  57.40   60.85  60.65        60.85            88.00
# 620      -      -  271.30      -       212.45                -
# 621      -      -  252.60      -       193.10                -
# 622  55.10  55.10   55.10  55.10        55.40             1.00
# 623  51.25  45.50   49.50  49.65        49.50            87.00
#
#     Turnover * in  ₹ Lakhs Premium Turnover ** in   ₹ Lakhs   Open Int  \
# 619                 554.70                            26.70  125500.00
# ...

# %%
data = data.iloc[::-1]
data.tail()
# Out:
#      Symbol         Date       Expiry Option type  Strike Price   Open   High  \
# 4  RELIANCE  08-Jan-2025  27-Feb-2025          CE        1130.0      -      -
# 3  RELIANCE  08-Jan-2025  27-Feb-2025          CE        1270.0  35.30  46.05
# 2  RELIANCE  08-Jan-2025  27-Feb-2025          CE        1120.0      -      -
# 1  RELIANCE  08-Jan-2025  27-Feb-2025          CE        1400.0   5.45   7.60
# 0  RELIANCE  08-Jan-2025  27-Feb-2025          CE        1260.0  39.75  51.75
#
#      Low   Close     LTP Settle Price No. of contracts Turnover * in  ₹ Lakhs  \
# 4      -  116.05       -       148.95                -                      -
# 3  35.30   43.10   43.00        43.10           104.00                 682.58
# 2      -  170.00  170.00       158.20                -                      -
# 1   5.45    7.25    7.05         7.25          1380.00                9707.87
# 0  39.75   48.50   48.00        48.50           400.00                2616.14
#
# ...

# %%
data.columns
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Open',
#        'High', 'Low', 'Close', 'LTP', 'Settle Price', 'No. of contracts',
#        'Turnover * in  ₹ Lakhs', 'Premium Turnover ** in   ₹ Lakhs',
#        'Open Int', 'Change in OI', 'Underlying Value'],
#       dtype='object')

# %%
S = data.drop_duplicates(subset="Date")[['Date', 'Underlying Value']]
S.head(10)
# Out:
#             Date  Underlying Value
# 623  01-Jan-2025           1221.25
# 522  02-Jan-2025           1241.80
# 421  03-Jan-2025           1251.15
# 314  06-Jan-2025           1218.00
# 209  07-Jan-2025           1240.85
# 104  08-Jan-2025           1265.50

# %%
S.to_csv("../S_path.csv", index=False)

# %%
data.head()
# Out:
#        Symbol         Date       Expiry Option type  Strike Price   Open  \
# 623  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1220.0  46.10
# 622  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1210.0  55.10
# 621  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1040.0      -
# 620  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1020.0      -
# 619  RELIANCE  01-Jan-2025  27-Feb-2025          CE        1200.0  58.00
#
#       High    Low   Close    LTP Settle Price No. of contracts  \
# 623  51.25  45.50   49.50  49.65        49.50            87.00
# 622  55.10  55.10   55.10  55.10        55.40             1.00
# 621      -      -  252.60      -       193.10                -
# 620      -      -  271.30      -       212.45                -
# 619  63.75  57.40   60.85  60.65        60.85            88.00
#
#     Turnover * in  ₹ Lakhs Premium Turnover ** in   ₹ Lakhs   Open Int  \
# 623                 551.70                            21.00   58500.00
# ...

# %%
C = data[['Date', 'Expiry', 'Strike Price', 'Close']].copy()
C.head()
# Out:
#             Date       Expiry  Strike Price   Close
# 623  01-Jan-2025  27-Feb-2025        1220.0   49.50
# 622  01-Jan-2025  27-Feb-2025        1210.0   55.10
# 621  01-Jan-2025  27-Feb-2025        1040.0  252.60
# 620  01-Jan-2025  27-Feb-2025        1020.0  271.30
# 619  01-Jan-2025  27-Feb-2025        1200.0   60.85

# %%
# C['Close'] = C['Close'].replace('-', np.nan)
C = C[C["Close"] != "-"].copy()
C.to_csv("../C_grid.csv", index=False)

# %%
r = pd.read_csv('../Data/INDIR3TIB01STM.csv')
r['observation_date'] = pd.to_datetime(r['observation_date']).dt.strftime("%d-%b-%Y")
r.head()
# Out:
#   observation_date  INDIR3TIB01STM
# 0      01-Nov-2011        8.868967
# 1      01-Dec-2011        8.553580
# 2      01-Jan-2012        8.614225
# 3      01-Feb-2012        8.917875
# 4      01-Mar-2012        9.022660

# %%
r.to_csv('../r_path.csv', index=False)
